# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import pickle
import itertools
import json
import re
import sklearn

from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing
from sklearn import grid_search
from sklearn.externals import joblib
from sklearn.decomposition import PCA
from sklearn import cluster

sns.set()

# %%
cd ../scripts/
# Out:
# /home/ethan/Documents/insight/scripts

# %%
import cleanup_features

# %%
cd ../data/
# Out:
# /home/ethan/Documents/insight/data

# %%
c = pickle.load(open('cleanup_features_object_v4.pkl', 'rb'))

# %%
# c.df = c.df[c.df['has_badge']==1]
zip_codes = c.df['zip_code'].unique()
zip_mean = []
zip_std = []
lat = []
lon = []
for zc in zip_codes:
    zip_mean.append(c.df[c.df['zip_code']==zc]['hourly_rate'].mean())
    zip_std.append(c.df[c.df['zip_code']==zc]['hourly_rate'].std())
    lat.append(c.df[c.df['zip_code']==zc]['lat'].values[0])
    lon.append(c.df[c.df['zip_code']==zc]['lon'].values[0])

# %%
74.15 -73.75
# Out:
# 0.4000000000000057

# %%
plt.scatter(x=lon, y=lat, c=zip_mean, vmax=100, cmap='cubehelix')
plt.axis([-74.15, -73.75, 40.6, 41])
# cmap = plt.colorbar()
plt.xlabel('Longitude', fontsize=16, color="white")
plt.xticks(fontsize=12, color="white")
plt.ylabel('Latitude', fontsize=16, color="white")
plt.yticks(fontsize=12, color="white")
plt.title('Average hourly rates by zip code', fontsize=20, color="white")
# plt.cticks(color="white")
color_bar = plt.colorbar()                            #this one is a little bit
cbytick_obj = plt.getp(color_bar.ax.axes, 'yticklabels')                #tricky
plt.setp(cbytick_obj, color='w', fontsize=12)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
has_ivy = c.df[c.df['has_ivy_degree']==1]

zip_codes = has_ivy['zip_code'].unique()
tutors = []
lat = []
lon = []
for zc in zip_codes:
    tutors.append(c.df[c.df['zip_code']==zc].count()[0])
    lat.append(c.df[c.df['zip_code']==zc]['lat'].values[0])
    lon.append(c.df[c.df['zip_code']==zc]['lon'].values[0])

plt.scatter(x=lon, y=lat, c=tutors, cmap='cubehelix')

    
# has_ivy.plot(x='lon', y='lat', c=tutors, kind='scatter', cmap='cubehelix', vmax=150, alpha=.2)
plt.axis([-74.15, -73.75, 40.6, 41])
# cmap = plt.colorbar()
plt.xlabel('Longitude', fontsize=16, color="white")
plt.xticks(fontsize=12, color="white")
plt.ylabel('Latitude', fontsize=16, color="white")
plt.yticks(fontsize=12, color="white")
plt.title('Ivy league tutor density by zip code', fontsize=20, color="white")
color_bar = plt.colorbar()                            #this one is a little bit
cbytick_obj = plt.getp(color_bar.ax.axes, 'yticklabels')                #tricky
plt.setp(cbytick_obj, color='w', fontsize=12)

# zip_mean = []
# zip_std = []
# lat = []
# lon = []
# for zc in zip_codes:
#     rate.append(c.df[c.df['zip_code']==zc]['hourly_rate'].mean())
#     zip_std.append(c.df[c.df['zip_code']==zc]['hourly_rate'].std())
#     lat.append(c.df[c.df['zip_code']==zc]['lat'].values[0])
#     lon.append(c.df[c.df['zip_code']==zc]['lon'].values[0])
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
has_phd = c.df[c.df['cat_music']==1]

zip_codes = has_phd['zip_code'].unique()
tutors = []
lat = []
lon = []
for zc in zip_codes:
    tutors.append(c.df[c.df['zip_code']==zc].count()[0])
    lat.append(c.df[c.df['zip_code']==zc]['lat'].values[0])
    lon.append(c.df[c.df['zip_code']==zc]['lon'].values[0])

plt.scatter(x=lon, y=lat, c=tutors, cmap='cubehelix')

    
# has_ivy.plot(x='lon', y='lat', c=tutors, kind='scatter', cmap='cubehelix', vmax=150, alpha=.2)
plt.axis([-74.15, -73.75, 40.6, 41])
# cmap = plt.colorbar()
plt.xlabel('Longitude', fontsize=16, color="white")
plt.xticks(fontsize=12, color="white")
plt.ylabel('Latitude', fontsize=16, color="white")
plt.yticks(fontsize=12, color="white")
plt.title('Ivy league tutor density by zip code', fontsize=20, color="white")
color_bar = plt.colorbar()                            #this one is a little bit
cbytick_obj = plt.getp(color_bar.ax.axes, 'yticklabels')                #tricky
plt.setp(cbytick_obj, color='w', fontsize=12)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
cd sklearn/only_badges/
# Out:
# /home/ethan/Documents/insight/data/sklearn/only_badges

# %%
X = pickle.load(open('X.pkl', 'rb'))
scaler_X = pickle.load(open('scaler_X.pkl', 'rb'))

# %%
X_inv = scaler_X.inverse_transform(X)

# %%
interaction_features = ['rating_x_number_of_ratings', \
                            'lat_x_lon', \
                            'zip_radius_x_lat_x_lon', \
                            'avg_review_length_x_sent_score', \
                            'number_of_reviews_x_avg_review_length', \
                            'number_of_reviews_x_avg_review_sentiment', \
                            'number_of_ratings_x_number_of_reviews']

new_usable = list(c.usable_features)
for feat in interaction_features:
    new_usable.remove(feat)

# %%
X = c.df[new_usable].as_matrix().astype(np.float)
# X = (X - X.mean())
# for i in range(X.shape[1]):
#     X[:,i] = X[:,i]/np.std(X[:,i])
max_features=42
test = np.corrcoef(X[:,:max_features].transpose())

# %%
color = 'k'
plt.figure(figsize=(14,14))
plt.imshow(test, interpolation='none', cmap='seismic')
# max_features = max_features-1
plt.yticks(np.linspace(0,max_features,max_features+1), np.asanyarray(new_usable[:max_features]), fontsize=14, color=color)
plt.xticks(np.linspace(0,max_features,max_features+1), np.asanyarray(new_usable[:max_features]), \
           fontsize=14, rotation=90, color=color)

ax = plt.gca()
ax.grid(b=False)
# plt.colorbar()
color_bar = plt.colorbar()                            #this one is a little bit
cbytick_obj = plt.getp(color_bar.ax.axes, 'yticklabels')                #tricky
plt.setp(cbytick_obj, color=color, fontsize=16)
plt.title('Feature correlation coefficients', fontsize=30, color=color)

# %%
X_subj = c.df[c.possible_subjects].as_matrix().astype(np.float)
# X = (X - X.mean())
# for i in range(X.shape[1]):
#     X[:,i] = X[:,i]/np.std(X[:,i])
max_features=len(c.possible_subjects)
test = np.corrcoef(X_subj[:,:max_features].transpose())
# # len(c.possible_subjects[:max_features])
# X_subj[:,:max_features].shape
# c.possible_subjects[99]
# np.linspace(0, max_features, max_features+1)

# %%
color = 'k'
plt.figure(figsize=(30,30))
plt.imshow(test, interpolation='none', cmap='bwr')
# max_features = max_features+1
plt.yticks(np.linspace(0,max_features,max_features+1), np.asanyarray(c.possible_subjects[:max_features]), fontsize=14, color=color)
plt.xticks(np.linspace(0,max_features,max_features+1), np.asanyarray(c.possible_subjects[:max_features]), \
           fontsize=14, rotation=90, color=color)
plt.clim((-1,1))
ax = plt.gca()
ax.grid(b=False)
# plt.colorbar()
color_bar = plt.colorbar()                            #this one is a little bit
cbytick_obj = plt.getp(color_bar.ax.axes, 'yticklabels')                #tricky
plt.setp(cbytick_obj, color=color, fontsize=16)
plt.title('Feature correlation coefficients', fontsize=30, color=color)
# plt.grid(ls='solid')

# %%
# Out:
# 100

# %%
pca = PCA(n_components=10)
X_subj = c.df[c.possible_subjects].as_matrix().astype(np.float)
# scaler = preprocessing.StandardScaler()
# X_subj = scaler.fit_transform(X_subj)

y = c.df['hourly_rate'].as_matrix().astype(np.float)
pca.fit(X_subj)
# Out:
# PCA(copy=True, n_components=10, whiten=False)

# %%
print pca.explained_variance_ratio_
# print pca.components_[0,:]
# Out:
# [ 0.18451427  0.13612322  0.05904397  0.0425033   0.0335979   0.02653994
#   0.02443844  0.0200939   0.01828754  0.01519887]

# %%
plt.figure(figsize=(16,10))
plt.plot(pca.components_[0,:],'.')
plt.xticks(np.linspace(0,len(c.possible_subjects), len(c.possible_subjects)), \
           np.asanyarray(c.possible_subjects), rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7fcc2ea6cdd0>,
# ...
#  <a list of 100 Text xticklabel objects>)

# %%
X_subj = pca.transform(X_subj)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-f7a964fd2c54> in <module>()
# ----> 1 X_subj = pca.transform(X_subj)
#
# /home/ethan/.local/lib/python2.7/site-packages/sklearn/decomposition/pca.pyc in transform(self, X)
#     393         X = array2d(X)
#     394         if self.mean_ is not None:
# --> 395             X = X - self.mean_
#     396         X_transformed = fast_dot(X, self.components_.T)
#     397         return X_transformed
#
# ValueError: operands could not be broadcast together with shapes (5632,10) (249,)

# %%
X_subj.shape
# Out:
# (5632, 10)

# %%
plt.plot(X_subj[:,0], X_subj[:,1], 'k.')
# plt.xlim(x_min, x_max)
# plt.ylim(y_min, y_max)
# plt.colorbar()

# %%
km = cluster.KMeans()
km.fit(X_subj[:,:2])
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=8, n_init=10,
#     n_jobs=1, precompute_distances=True, random_state=None, tol=0.0001,
#     verbose=0)

# %%
# Step size of the mesh. Decrease to increase the quality of the VQ.
h = .02     # point in the mesh [x_min, m_max]x[y_min, y_max].

# Plot the decision boundary. For that, we will assign a color to each
x_min, x_max = X_subj[:, 0].min(), X_subj[:, 0].max()
y_min, y_max = X_subj[:, 1].min(), X_subj[:, 1].max()
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Obtain labels for each point in mesh. Use last trained model.
Z = km.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1)
plt.clf()
plt.imshow(Z, interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap=plt.cm.Paired,
           aspect='auto', origin='lower')

plt.plot(X_subj[:, 0], X_subj[:, 1], 'k.', markersize=2)
# Plot the centroids as a white X
centroids = km.cluster_centers_
plt.scatter(centroids[:, 0], centroids[:, 1],
            marker='x', s=169, linewidths=3,
            color='w', zorder=10)
plt.title('K-means clustering on the digits dataset (PCA-reduced data)\n'
          'Centroids are marked with white cross')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
# plt.xticks(())
# plt.yticks(())
plt.show()

# %%
feats = list(c.possible_subjects)
X_feats = c.df[feats].as_matrix().astype(np.float)
# for subj in c.qualified_subjects:
#     feats.remove(subj)

# %%
person = X_feats[3,:]

# %%
def cosine_similarity(arr, mat):
    sim = np.empty(mat.shape[0])
    for i in xrange(0, mat.shape[0]):
        sim[i] = np.sum(mat[i,:]*arr)/np.sqrt(np.sum(mat[i,:]**2))/np.sqrt(np.sum(arr**2))
    return sim

# %%
inter = cosine_similarity(person, X_feats)
sorted_idx = np.argsort(inter)
c.df.iloc[sorted_idx[-30:]][feats[:20]]
# plt.plot(inter[sorted_idx][-50:])
# Out:
#      ACT English ACT Math ACT Reading ACT Science ADD/ADHD Accounting  \
# 782         True     True        True        True    False      False
# 158         True     True        True        True     True      False
# 421         True     True        True        True    False      False
# 2783        True     True        True       False    False      False
# 5497        True     True        True        True    False      False
# 5498        True     True        True        True    False      False
# 5595        True     True        True        True    False      False
# 607         True     True        True        True    False      False
# 3621        True     True        True        True    False      False
# 1366        True     True        True        True    False      False
# 3417        True     True        True        True    False      False
# 138         True     True        True       False    False      False
# ...

# %%
feats_no_subj = list(c.usable_features)
feats_no_subj = [x for x in c.usable_features if x not in c.possible_subjects \
                 and x not in c.qualified_subjects and x not in c.cat_features]
# feats_no_subj = [x for x in feats_n if x not in c.qualified_subjects]

# %%
feats_no_subj
# Out:
# ['EdD',
#  'Enrolled',
#  'Graduate_Coursework',
#  'J.D.',
#  'MBA',
#  'MD',
#  'MEd',
#  'Masters',
#  'Other',
#  'PhD',
#  'avg_review_length',
#  'badge_hours',
#  'days_since_last_review',
#  'has_rating',
#  'lat',
#  'lon',
#  'number_of_ratings',
#  'number_of_reviews',
#  'profile_picture',
#  'rating',
#  'zip_code',
#  'zip_radius',
#  'rating_x_number_of_ratings',
#  'has_ivy_degree',
#  'has_background_check',
#  'days_since_background_check',
#  'response_time',
#  'avg_review_sentiment',
#  'lat_x_lon',
#  'zip_radius_x_lat_x_lon',
#  'avg_review_length_x_sent_score',
#  'number_of_reviews_x_avg_review_length',
#  'number_of_reviews_x_avg_review_sentiment',
#  'number_of_ratings_x_number_of_reviews']

# %%
X_feats = c.df.iloc[sorted_idx[-50:]][feats_no_subj].as_matrix().astype(np.float)
person = X_feats[-1:,:]
sim = cosine_similarity(person, X_feats)

# %%
sorted_idx_2 = np.argsort(sim)
test = c.df.iloc[sorted_idx[-50:]]['hourly_rate'].copy()
y = test.iloc[sorted_idx_2].as_matrix().astype(np.float)

# %%
sns.kdeplot(y, shade=True)
# plt.hist(y, bins=50)
