# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import pickle
import itertools
import json
import re
import sklearn

from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing
from sklearn import grid_search
from sklearn import learning_curve

sns.set()

# %%
cd ../data/sklearn/
# Out:
# /home/ethan/Documents/insight/data/sklearn

# %%
X = pickle.load(open('X.pkl', 'rb'))
y = pickle.load(open('y.pkl', 'rb'))
scaler_X = pickle.load(open('scaler_X.pkl', 'rb'))
scaler_y = pickle.load(open('scaler_y.pkl', 'rb'))

# %%
# Save for later
X_train, X_final_test, y_train, y_final_test = \
    cross_validation.train_test_split(X, \
                                      y, \
                                      test_size=.2, \
                                      random_state=19)
# Cross-validation
kf = cross_validation.KFold(X_train.shape[0], \
                            n_folds=10, \
                            shuffle=True, \
                            random_state=13)

# %%
rf = ensemble.RandomForestRegressor()

# Originally did for n_estimators = [10, 20, 50, 100, 200, 500, 1000]
# and got best n_estimators = 1000, max_features='sqrt'
parameters = {'n_estimators':[1000, 2000, 3000, 5000], \
              'max_features':['sqrt']}

clf = grid_search.GridSearchCV(rf, parameters, cv=kf, verbose=10)
clf.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ... max_features=sqrt, n_estimators=1000, score=0.084587 -   9.3s
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ... max_features=sqrt, n_estimators=1000, score=0.134419 -   9.3s
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    9.3s
# [Parallel(n_jobs=1)]: Done   2 jobs       | elapsed:   18.6s
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ... max_features=sqrt, n_estimators=1000, score=0.164633 -   9.4s
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ... max_features=sqrt, n_estimators=1000, score=0.153331 -   9.2s
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ... max_features=sqrt, n_estimators=1000, score=0.113873 -   9.4s
# [CV] max_features=sqrt, n_estimators=1000 ............................
# ...

# %%
clf.best_params_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 1000}

# %%
y_train_trans = scaler_y.inverse_transform(y_train)
y_pred_trans = scaler_y.inverse_transform(clf.predict(X_train))

# %%
mse = metrics.mean_squared_error(y_train_trans, y_pred_trans)
dumb_mse = metrics.mean_squared_error(y_train_trans, np.ones(len(y_train_trans))*np.mean(y_train_trans))

print 'MSE: ' + str(mse)
print 'Dumb MSE (always predicting average): ' + str(dumb_mse)
print 'MSE/Dumb MSE: ' + str(mse/dumb_mse)
print 'R^2 score: ' + str(clf.score(X_train, y_train))
# Out:
# MSE: 64.8311007972
# Dumb MSE (always predicting average): 552.760003682
# MSE/Dumb MSE: 0.117286164638
# R^2 score: 0.882713835362

# %%
train_sizes, train_scores, test_scores = learning_curve.learning_curve(clf.best_estimator_, X_train, y_train, cv=10)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)
plt.grid()

plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1,
                 color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
         label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
         label="Cross-validation score")

plt.legend(loc="best")

# %%
rf_no_oob = ensemble.RandomForestRegressor(n_estimators=5000, max_features='auto', oob_score=True, \
                                    verbose = 5)
rf_no_oob.fit(X_train, y_train)
# scores = cross_validation.cross_val_score(rf_no_oob, X_train, y_train, cv=kf, verbose=10)
# Out:
# building tree 1 of 5000
# building tree 2 of 5000
# building tree 3 of 5000
# building tree 4 of 5000
# building tree 5 of 5000
# building tree 6 of 5000
# building tree 7 of 5000
# building tree 8 of 5000
# building tree 9 of 5000
# building tree 10 of 5000
# building tree 11 of 5000
# building tree 12 of 5000
# building tree 13 of 5000
# building tree 14 of 5000
# building tree 15 of 5000
# building tree 16 of 5000
# building tree 17 of 5000
# building tree 18 of 5000
# building tree 19 of 5000
# building tree 20 of 5000
# building tree 21 of 5000
# building tree 22 of 5000
# building tree 23 of 5000
# building tree 24 of 5000
# building tree 25 of 5000
# building tree 26 of 5000
# building tree 27 of 5000
# building tree 28 of 5000
# building tree 29 of 5000
# building tree 30 of 5000
# building tree 31 of 5000
# building tree 32 of 5000
# building tree 33 of 5000
# building tree 34 of 5000
# building tree 35 of 5000
# building tree 36 of 5000
# building tree 37 of 5000
# ...

# %%
rf_no_oob.oob_score_ # whomp
# Out:
# 0.11218643854143118

# %%
X_train_unscaled = scaler_X.inverse_transform(X_train)
y_train_unscaled = scaler_y.inverse_transform(y_train)
rf_no_oob = ensemble.RandomForestRegressor(n_estimators=1000, max_features='sqrt', oob_score=True, \
                                    verbose = 5)
rf_no_oob.fit(X_train, y_train)
# Out:
# building tree 1 of 1000
# building tree 2 of 1000
# building tree 3 of 1000
# building tree 4 of 1000
# building tree 5 of 1000
# building tree 6 of 1000
# building tree 7 of 1000
# building tree 8 of 1000
# building tree 9 of 1000
# building tree 10 of 1000
# building tree 11 of 1000
# building tree 12 of 1000
# building tree 13 of 1000
# building tree 14 of 1000
# building tree 15 of 1000
# building tree 16 of 1000
# building tree 17 of 1000
# building tree 18 of 1000
# building tree 19 of 1000
# building tree 20 of 1000
# building tree 21 of 1000
# building tree 22 of 1000
# building tree 23 of 1000
# building tree 24 of 1000
# building tree 25 of 1000
# building tree 26 of 1000
# building tree 27 of 1000
# building tree 28 of 1000
# building tree 29 of 1000
# building tree 30 of 1000
# building tree 31 of 1000
# building tree 32 of 1000
# building tree 33 of 1000
# building tree 34 of 1000
# building tree 35 of 1000
# building tree 36 of 1000
# building tree 37 of 1000
# ...

# %%
rf_no_oob.oob_score_
# Out:
# 0.13835753622221481

# %%
rf_no_oob = ensemble.RandomForestRegressor(n_estimators=1000, max_features='sqrt', oob_score=True, \
                                    verbose = 5)
rf_no_oob.fit(X_train_unscaled, y_train_unscaled)
# Out:
# building tree 1 of 1000
# building tree 2 of 1000
# building tree 3 of 1000
# building tree 4 of 1000
# building tree 5 of 1000
# building tree 6 of 1000
# building tree 7 of 1000
# building tree 8 of 1000
# building tree 9 of 1000
# building tree 10 of 1000
# building tree 11 of 1000
# building tree 12 of 1000
# building tree 13 of 1000
# building tree 14 of 1000
# building tree 15 of 1000
# building tree 16 of 1000
# building tree 17 of 1000
# building tree 18 of 1000
# building tree 19 of 1000
# building tree 20 of 1000
# building tree 21 of 1000
# building tree 22 of 1000
# building tree 23 of 1000
# building tree 24 of 1000
# building tree 25 of 1000
# building tree 26 of 1000
# building tree 27 of 1000
# building tree 28 of 1000
# building tree 29 of 1000
# building tree 30 of 1000
# building tree 31 of 1000
# building tree 32 of 1000
# building tree 33 of 1000
# building tree 34 of 1000
# building tree 35 of 1000
# building tree 36 of 1000
# building tree 37 of 1000
# ...

# %%
rf_no_oob.oob_score_ # no real difference
# Out:
# 0.13852578089080703

# %%
rf_no_oob = ensemble.RandomForestRegressor(n_estimators=10000, max_features='sqrt', oob_score=True, \
                                    verbose = 5)
rf_no_oob.fit(X_train, y_train)
# Out:
# building tree 1 of 10000
# building tree 2 of 10000
# building tree 3 of 10000
# building tree 4 of 10000
# building tree 5 of 10000
# building tree 6 of 10000
# building tree 7 of 10000
# building tree 8 of 10000
# building tree 9 of 10000
# building tree 10 of 10000
# building tree 11 of 10000
# building tree 12 of 10000
# building tree 13 of 10000
# building tree 14 of 10000
# building tree 15 of 10000
# building tree 16 of 10000
# building tree 17 of 10000
# building tree 18 of 10000
# building tree 19 of 10000
# building tree 20 of 10000
# building tree 21 of 10000
# building tree 22 of 10000
# building tree 23 of 10000
# building tree 24 of 10000
# building tree 25 of 10000
# building tree 26 of 10000
# building tree 27 of 10000
# building tree 28 of 10000
# building tree 29 of 10000
# building tree 30 of 10000
# building tree 31 of 10000
# building tree 32 of 10000
# building tree 33 of 10000
# building tree 34 of 10000
# building tree 35 of 10000
# building tree 36 of 10000
# ...
