# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import itertools
import json
import re
import sklearn

from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing

sns.set()
matplotlib.rcParams['savefig.dpi'] = 1.5 * matplotlib.rcParams['savefig.dpi']

# %%
cd ../scripts/
# Out:
# /home/ethan/Documents/insight/scripts

# %%
from features import features

# %%
cd ../data
# Out:
# /home/ethan/Documents/insight/data

# %%
path = 'nyc_20150116.txt'
d = features(path)
d.all_features()
d.df.head()

# %%
from pyzipcode import ZipCodeDatabase
zcdb = ZipCodeDatabase()

# %%
def get_lat_lon(row, zcdb):
    
    try:
        zip_code = zcdb[int(row)]
        return Series({'lat':zip_code.latitude, 'lon':zip_code.longitude})
    except:
        return Series({'lat':0,'lon':0})
    
lat_lon = d.df['zip_code'].apply(lambda x: get_lat_lon(x, zcdb))
lat_lon = pd.concat(['lat_lon', d.df['hourly_rate']], axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-f6ba12c48334> in <module>()
#       9
#      10 lat_lon = d.df['zip_code'].apply(lambda x: get_lat_lon(x, zcdb))
# ---> 11 lat_lon = pd.concat(['lat_lon', d.df['hourly_rate']], axis=1)
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     720                        keys=keys, levels=levels, names=names,
#     721                        verify_integrity=verify_integrity,
# --> 722                        copy=copy)
#     723     return op.get_result()
#     724
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     771         for obj in objs:
# ...

# %%
lat_lon[lat_lon['lat']!=0].plot(kind='scatter',x='lat',y='lon', alpha=.1)

# %%
plt.imshow(lat_lon[lat_lon['lat']!=0])
