# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import itertools
import json
import re
import sklearn

from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing

sns.set()
matplotlib.rcParams['savefig.dpi'] = 1.5 * matplotlib.rcParams['savefig.dpi']

# %%
path = 'nyc_20150116.txt'
df = DataFrame([json.loads(line) for line in open(path)])

# %%
## Just get the subjects (ignore topics)
just_subjects = df['raw_subjects']
just_subjects = just_subjects.apply(lambda x: x.values()) # Get rid of topics
just_subjects = just_subjects.apply(lambda x: list(set(y.strip(' ') for z in x for y in z))) # Flatten lists (see below for better?)
just_subjects.name = 'just_subjects'
df = pd.concat([df, just_subjects], axis=1)
df.head()
# Out:
#                      badge                                          education  \
# 0  Over 100 tutoring hours  {u'Massachusets Institute of Technology': [u'E...
# 1   Over 50 tutoring hours  {u'Universidad de Barcelona': [u'MEd'], u'Inst...
# 2  Over 100 tutoring hours  {u'Yale College': [u'History'], u'Columbia Uni...
# 3  Over 400 tutoring hours                            {u'no_university': u''}
# 4  Over 200 tutoring hours  {u'University of California at Santa Barbara':...
#
#    hourly_rate                                    linked_subjects       name  \
# 0          120  {u'Sports/Recreation': [], u'Business': [], u'...   Malik K.
# 1          120  {u'Homeschool': [], u'Language': [], u'Corpora...   Pablo E.
# 2          140  {u'Test Preparation': [], u'Business': [], u'C...  Horace G.
# 3          150                          {u'Test Preparation': []}      JD M.
# 4           60  {u'English': [], u'Homeschool': [], u'Elementa...  Cheryl F.
#
#    number_of_ratings profile_picture  \
# 0                  7            True
# 1                 30            True
# 2                 66            True
# 3                106            True
# 4                 20            True
#
#                                        qual_subjects  rating  \
# 0  {u'Sports/Recreation': [], u'Business': [u'Mic...       5
# 1  {u'Homeschool': [], u'Language': [], u'Corpora...       5
# 2  {u'Test Preparation': [u'ACT English, ', u'ACT...       5
# 3                          {u'Test Preparation': []}       5
# 4  {u'English': [u'English, ', u'Literature, ', u...       5
#
#                                         raw_subjects zip_code zip_radius  \
# 0  {u'Sports/Recreation': [u'Martial Arts'], u'Bu...    10030         10
# 1  {u'Homeschool': [u'Spanish'], u'Language': [u'...    10028          3
# 2  {u'Test Preparation': [u'ACT English', u'ACT M...    10019         40
# 3                   {u'Test Preparation': [u'LSAT']}    10036         40
# 4  {u'English': [u'English', u'ESL/ESOL', u'Gramm...    10012         40
#
#                                        just_subjects
# 0  [SAT Math, ACT English, Calculus, ACT Science,...
# 1                                          [Spanish]
# 2  [ACT Science, SAT Writing, SAT Reading, Busine...
# 3                                             [LSAT]
# 4  [Literature, Grammar, Vocabulary, Elementary (...

# %% [markdown]
# ## Convert subject mentions to boolean features

# %%
possible_subjects = list(set(itertools.chain.from_iterable(df['just_subjects'].values)))

# %%
dummies_df = DataFrame(columns=possible_subjects, dtype='Bool')

def subj_to_bool(row, categories):
    """ Convert subjects to boolean values"""
    out_row = []
    for subj in categories:
        if subj in row:
            out_row.append(True)
        else:
            out_row.append(False)
    return np.array(out_row)

# %%
# Make new boolean column for each subject. Place in dummies_df DataFrame
for i in xrange(0, df.shape[0]):
    dummies_df.loc[i] = subj_to_bool(df['just_subjects'].loc[i], possible_subjects)
dummies_df.head()
# Out:
#    STATA  Cello   Yoga Microsoft PowerPoint Biochemistry Sign Language  \
# 0  False  False  False                False        False         False
# 1  False  False  False                False        False         False
# 2  False  False  False                False        False         False
# 3  False  False  False                False        False         False
# 4  False  False  False                False        False         False
#
#   Microbiology  Tango ACT English Religion    ...    Series 63  \
# 0        False  False        True    False    ...        False
# 1        False  False       False    False    ...        False
# 2        False  False        True    False    ...        False
# 3        False  False       False    False    ...        False
# 4        False  False       False    False    ...        False
#
#   Networking (Computer) Visual Basic Spanish Trombone Music History  \
# 0                 False        False   False    False         False
# 1                 False        False    True    False         False
# 2                 False        False   False    False         False
# 3                 False        False   False    False         False
# 4                 False        False   False    False         False
#
#   Bible Studies  NCLEX   Film Geography
# 0         False  False  False     False
# 1         False  False  False     False
# 2         False  False  False     False
# 3         False  False  False     False
# 4         False  False  False     False
#
# [5 rows x 260 columns]

# %%
df_comb = pd.concat([df, dummies_df], axis=1)

# %% [markdown]
# ## Plot average hourly rate with standard deviation vs. mention of subject

# %%
def hourly_rate_by_subject(df, column):
    out = {}
    for subject in column:
        tmp = df[df[subject]==True]['hourly_rate']
        out[subject] = {'mean':tmp.mean(), 'stdev':tmp.std()}
    return DataFrame(out).transpose()

hourly_subject_rates = hourly_rate_by_subject(df_comb, possible_subjects)
hourly_subject_rates.head()
# Out:
#                   mean      stdev
# ACT English  62.613316  32.234780
# ACT Math     64.380507  32.361646
# ACT Reading  62.637097  31.266923
# ACT Science  68.776812  36.236618
# ADD/ADHD     58.498891  19.379872

# %%
hourly_subject_rates = hourly_subject_rates.sort(axis=0, columns='mean')

# %%
current_palette = sns.color_palette()

# %%
fig, ax = plt.subplots()

plt.errorbar(np.linspace(0,1,len(hourly_subject_rates.index.tolist())), \
             hourly_subject_rates['mean'], yerr=hourly_subject_rates['stdev'], \
             ecolor=current_palette[2], alpha=0.5)
plt.xticks(np.linspace(0,1,len(hourly_subject_rates.index.tolist())/20), \
           hourly_subject_rates.index.tolist()[::20], rotation=40, \
           horizontalalignment='right')

plt.axis([0, 1, 0, 180])
plt.xlabel('Tutoring Subject', fontsize=16)
plt.ylabel('Hourly Rate', fontsize=16)

# %% [markdown]
# ## Convert badge info to hours and boolean

# %%
numbers_regex = re.compile('\d+')

def get_badge_info(row, numbers_regex):
    row_regex = re.findall(numbers_regex, row)
    if len(row_regex)==1:
        return Series({'has_badge':True, 'badge_hours':int(row_regex[0])})
    else:
        return Series({'has_badge':False, 'badge_hours':0})

badge_df = df['badge'].apply(lambda x: get_badge_info(x, numbers_regex))
badge_df.head()
# Out:
#    badge_hours has_badge
# 0          100      True
# 1           50      True
# 2          100      True
# 3          400      True
# 4          200      True

# %%
df_comb = pd.concat([df_comb, badge_df], axis=1)
df_comb = df_comb.drop('badge', axis=1)
df_comb.head()
# Out:
#                                            education  hourly_rate  \
# 0  {u'Massachusets Institute of Technology': [u'E...          120
# 1  {u'Universidad de Barcelona': [u'MEd'], u'Inst...          120
# 2  {u'Yale College': [u'History'], u'Columbia Uni...          140
# 3                            {u'no_university': u''}          150
# 4  {u'University of California at Santa Barbara':...           60
#
#                                      linked_subjects       name  \
# 0  {u'Sports/Recreation': [], u'Business': [], u'...   Malik K.
# 1  {u'Homeschool': [], u'Language': [], u'Corpora...   Pablo E.
# 2  {u'Test Preparation': [], u'Business': [], u'C...  Horace G.
# 3                          {u'Test Preparation': []}      JD M.
# 4  {u'English': [], u'Homeschool': [], u'Elementa...  Cheryl F.
#
#    number_of_ratings profile_picture  \
# 0                  7            True
# 1                 30            True
# 2                 66            True
# 3                106            True
# 4                 20            True
#
#                                        qual_subjects  rating  \
# 0  {u'Sports/Recreation': [], u'Business': [u'Mic...       5
# 1  {u'Homeschool': [], u'Language': [], u'Corpora...       5
# 2  {u'Test Preparation': [u'ACT English, ', u'ACT...       5
# 3                          {u'Test Preparation': []}       5
# 4  {u'English': [u'English, ', u'Literature, ', u...       5
#
#                                         raw_subjects zip_code    ...     \
# 0  {u'Sports/Recreation': [u'Martial Arts'], u'Bu...    10030    ...
# 1  {u'Homeschool': [u'Spanish'], u'Language': [u'...    10028    ...
# 2  {u'Test Preparation': [u'ACT English', u'ACT M...    10019    ...
# 3                   {u'Test Preparation': [u'LSAT']}    10036    ...
# 4  {u'English': [u'English', u'ESL/ESOL', u'Gramm...    10012    ...
#
#   Visual Basic Spanish Trombone Music History Bible Studies  NCLEX   Film  \
# 0        False   False    False         False         False  False  False
# 1        False    True    False         False         False  False  False
# 2        False   False    False         False         False  False  False
# 3        False   False    False         False         False  False  False
# 4        False   False    False         False         False  False  False
#
#   Geography badge_hours has_badge
# 0     False         100      True
# 1     False          50      True
# 2     False         100      True
# 3     False         400      True
# 4     False         200      True
#
# [5 rows x 274 columns]

# %% [markdown]
# ## Cleanup ratings and convert to boolean

# %%
has_rating = df_comb['rating'].apply(lambda x: np.isnan(x))
has_rating.name = 'has_rating'
df_comb = pd.concat([df_comb, has_rating], axis=1)

# %%
df_comb['rating'].apply(lambda x: np.isnan(x))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 5811    False
# 5812    False
# 5813    False
# 5814     True
# 5815     True
# 5816     True
# 5817    False
# 5818    False
# 5819    False
# 5820    False
# 5821    False
# 5822    False
# 5823    False
# 5824    False
# 5825     True
# Name: rating, Length: 5826, dtype: bool

# %%
subject_sort = df_comb[df_comb[possible_subjects]==True][possible_subjects].sum()
subject_sort.sort()
print subject_sort.describe()
# Out:
# count     260.000000
# mean      285.815385
# std       467.572608
# min         1.000000
# 25%        32.750000
# 50%        97.500000
# 75%       289.250000
# max      2762.000000
# dtype: float64

# %%
subject_sort.plot(fontsize=12)
plt.xlabel('Tutoring Subject', fontsize=16)
plt.ylabel('Counts', fontsize=16)

# %% [markdown]
# ## Play with some scikit-learn

# %%
y = df_comb['hourly_rate'].as_matrix().astype(np.float32)

# %%
df_comb.head()
# Out:
#                                            education  hourly_rate  \
# 0  {u'Massachusets Institute of Technology': [u'E...          120
# 1  {u'Universidad de Barcelona': [u'MEd'], u'Inst...          120
# 2  {u'Yale College': [u'History'], u'Columbia Uni...          140
# 3                            {u'no_university': u''}          150
# 4  {u'University of California at Santa Barbara':...           60
#
#                                      linked_subjects       name  \
# 0  {u'Sports/Recreation': [], u'Business': [], u'...   Malik K.
# 1  {u'Homeschool': [], u'Language': [], u'Corpora...   Pablo E.
# 2  {u'Test Preparation': [], u'Business': [], u'C...  Horace G.
# 3                          {u'Test Preparation': []}      JD M.
# 4  {u'English': [], u'Homeschool': [], u'Elementa...  Cheryl F.
#
#    number_of_ratings profile_picture  \
# 0                  7            True
# 1                 30            True
# 2                 66            True
# 3                106            True
# 4                 20            True
#
#                                        qual_subjects  rating  \
# 0  {u'Sports/Recreation': [], u'Business': [u'Mic...       5
# 1  {u'Homeschool': [], u'Language': [], u'Corpora...       5
# 2  {u'Test Preparation': [u'ACT English, ', u'ACT...       5
# 3                          {u'Test Preparation': []}       5
# 4  {u'English': [u'English, ', u'Literature, ', u...       5
#
#                                         raw_subjects zip_code    ...      \
# 0  {u'Sports/Recreation': [u'Martial Arts'], u'Bu...    10030    ...
# 1  {u'Homeschool': [u'Spanish'], u'Language': [u'...    10028    ...
# 2  {u'Test Preparation': [u'ACT English', u'ACT M...    10019    ...
# 3                   {u'Test Preparation': [u'LSAT']}    10036    ...
# 4  {u'English': [u'English', u'ESL/ESOL', u'Gramm...    10012    ...
#
#   Spanish Trombone Music History Bible Studies  NCLEX   Film Geography  \
# 0   False    False         False         False  False  False     False
# 1    True    False         False         False  False  False     False
# 2   False    False         False         False  False  False     False
# 3   False    False         False         False  False  False     False
# 4   False    False         False         False  False  False     False
#
#   badge_hours has_badge has_rating
# 0         100      True      False
# 1          50      True      False
# 2         100      True      False
# 3         400      True      False
# 4         200      True      False
#
# [5 rows x 275 columns]

# %%
X_features = ['profile_picture', 'has_badge', 'has_rating']
X_features.extend(possible_subjects)
X = df_comb[X_features].as_matrix().astype(np.float)

scaler = preprocessing.StandardScaler()
X = scaler.fit_transform(X)

# %%
def stratified_cv(X, y, clf_class):
    skf = cross_validation.StratifiedKFold(y, n_folds=10, shuffle=True)
    y_pred = y.copy()
    for train_index, test_index in skf:
        X_train, X_test = X[train_index], X[test_index]
        y_train = y[train_index]
        clf_class.fit(X_train, y_train)
        y_pred[test_index] = clf_class.predict(X_test)
    return y_pred

# %%
clf_lin = sklearn.linear_model.LinearRegression()
stratified_cv(X, y, clf_lin)
# Out:
# /home/ethan/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:413: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=10.
#   % (min_labels, self.n_folds)), Warning)
# array([ 81.10888672,  56.84612274,  91.41203308, ...,  45.88658524,
#         58.30757141,  83.06916809], dtype=float32)

# %% [raw]
# def remove_sparse_subjects(df, subjects, threshold):

# %%
def fix_masters(ed_list):
    fixed_list = []
    for degree in ed_list:
        if degree=='Master&#39;s':
            fixed_list.append('Masters')
        else:
            fixed_list.append(degree)
    return fixed_list

ed = df_comb['education'].apply(lambda x: [v[0] for v in x.itervalues() if len(v)>0])
ed = ed.apply(lambda x: fix_masters(x))

def get_education(ed_list):
    degrees = {'MEd':False, 'MBA':False, 'Masters':False, 'PhD':False, 'J.D.':False, 'MD':False}
    check = True
    for degree in degrees.keys():
        if degree in ed_list:
            degrees[degree] = True
            check = False
    degrees['Bachelors'] = check
    return Series(degrees)

ed = ed.apply(lambda x: get_education(x))

print ed
# Out:
#      Bachelors   J.D.    MBA     MD    MEd Masters    PhD
# 0        False  False   True  False  False   False  False
# 1        False  False   True  False   True   False  False
# 2        False  False  False  False  False    True  False
# 3         True  False  False  False  False   False  False
# 4        False  False  False  False  False    True  False
# 5        False  False  False  False  False    True  False
# 6        False   True  False  False  False    True  False
# 7        False  False  False  False  False    True  False
# 8         True  False  False  False  False   False  False
# 9         True  False  False  False  False   False  False
# 10        True  False  False  False  False   False  False
# 11       False   True  False  False  False   False  False
# 12       False  False  False  False  False    True  False
# 13        True  False  False  False  False   False  False
# 14        True  False  False  False  False   False  False
# 15        True  False  False  False  False   False  False
# 16        True  False  False  False  False   False  False
# 17        True  False  False  False  False   False  False
# 18       False  False  False  False  False    True  False
# 19       False  False  False  False  False   False   True
# 20        True  False  False  False  False   False  False
# 21       False  False  False  False  False    True  False
# 22       False  False  False  False  False    True   True
# 23       False  False  False  False  False    True  False
# 24       False  False  False  False  False    True  False
# 25       False  False  False  False  False    True  False
# 26       False  False  False  False  False    True  False
# 27        True  False  False  False  False   False  False
# 28       False  False  False  False  False    True  False
# 29        True  False  False  False  False   False  False
# ...        ...    ...    ...    ...    ...     ...    ...
# 5796     False  False  False  False  False    True  False
# 5797      True  False  False  False  False   False  False
# 5798     False  False  False  False  False    True  False
# 5799      True  False  False  False  False   False  False
# 5800      True  False  False  False  False   False  False
# 5801      True  False  False  False  False   False  False
# 5802      True  False  False  False  False   False  False
# 5803      True  False  False  False  False   False  False
# 5804      True  False  False  False  False   False  False
# 5805      True  False  False  False  False   False  False
# 5806     False  False  False  False  False    True  False
# 5807     False  False  False  False  False    True  False
# 5808      True  False  False  False  False   False  False
# 5809      True  False  False  False  False   False  False
# 5810     False  False  False  False  False    True  False
# 5811     False  False  False  False  False    True  False
# 5812     False  False   True  False  False    True  False
# 5813      True  False  False  False  False   False  False
# 5814     False  False  False  False  False    True  False
# 5815     False  False  False  False  False   False   True
# 5816     False  False  False  False  False    True  False
# 5817     False  False  False  False  False    True   True
# 5818      True  False  False  False  False   False  False
# 5819      True  False  False  False  False   False  False
# 5820      True  False  False  False  False   False  False
# 5821     False  False  False  False  False    True  False
# 5822      True  False  False  False  False   False  False
# 5823      True  False  False  False  False   False  False
# 5824      True  False  False  False  False   False  False
# 5825     False   True   True  False  False   False  False
#
# [5826 rows x 7 columns]

# %%
df_comb = pd.concat([df_comb, ed], axis=1)
df_comb.head()
# Out:
#                                            education  hourly_rate  \
# 0  {u'Massachusets Institute of Technology': [u'E...          120
# 1  {u'Universidad de Barcelona': [u'MEd'], u'Inst...          120
# 2  {u'Yale College': [u'History'], u'Columbia Uni...          140
# 3                            {u'no_university': u''}          150
# 4  {u'University of California at Santa Barbara':...           60
#
#                                      linked_subjects       name  \
# 0  {u'Sports/Recreation': [], u'Business': [], u'...   Malik K.
# 1  {u'Homeschool': [], u'Language': [], u'Corpora...   Pablo E.
# 2  {u'Test Preparation': [], u'Business': [], u'C...  Horace G.
# 3                          {u'Test Preparation': []}      JD M.
# 4  {u'English': [], u'Homeschool': [], u'Elementa...  Cheryl F.
#
#    number_of_ratings profile_picture  \
# 0                  7            True
# 1                 30            True
# 2                 66            True
# 3                106            True
# 4                 20            True
#
#                                        qual_subjects  rating  \
# 0  {u'Sports/Recreation': [], u'Business': [u'Mic...       5
# 1  {u'Homeschool': [], u'Language': [], u'Corpora...       5
# 2  {u'Test Preparation': [u'ACT English, ', u'ACT...       5
# 3                          {u'Test Preparation': []}       5
# 4  {u'English': [u'English, ', u'Literature, ', u...       5
#
#                                         raw_subjects zip_code  ...    \
# 0  {u'Sports/Recreation': [u'Martial Arts'], u'Bu...    10030  ...
# 1  {u'Homeschool': [u'Spanish'], u'Language': [u'...    10028  ...
# 2  {u'Test Preparation': [u'ACT English', u'ACT M...    10019  ...
# 3                   {u'Test Preparation': [u'LSAT']}    10036  ...
# 4  {u'English': [u'English', u'ESL/ESOL', u'Gramm...    10012  ...
#
#   badge_hours has_badge has_rating Bachelors   J.D.    MBA     MD    MEd  \
# 0         100      True      False     False  False   True  False  False
# 1          50      True      False     False  False   True  False   True
# 2         100      True      False     False  False  False  False  False
# 3         400      True      False      True  False  False  False  False
# 4         200      True      False     False  False  False  False  False
#
#   Masters    PhD
# 0   False  False
# 1   False  False
# 2    True  False
# 3   False  False
# 4    True  False
#
# [5 rows x 282 columns]

# %%
df_comb[df_comb['Bachelors']==True]['hourly_rate'].describe()
# Out:
# count    3224.000000
# mean       52.966191
# std        21.538652
# min        15.000000
# 25%        40.000000
# 50%        50.000000
# 75%        60.000000
# max       400.000000
# Name: hourly_rate, dtype: float64

# %%
degrees = ['Bachelors', 'J.D.', 'MBA', 'MEd', 'Masters', 'PhD']

degree_plot = DataFrame()
for degree in degrees:
    d = Series(df_comb[df_comb[degree]==True]['hourly_rate'], name=degree)
    degree_plot = pd.concat([degree_plot, d], axis=1)

degree_plot.boxplot(fontsize=12)
plt.ylim(0, 150)
plt.xlabel('Degree', fontsize=16)
plt.ylabel('Hourly Rate', fontsize=16)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.py:2601: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   warnings.warn(msg, FutureWarning)

# %%
plt.boxplot(df_comb[df_comb['PhD']]['hourly_rate'].as_matrix(), whis='range')
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff4ed7a35d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff4ed732290>,
#   <matplotlib.lines.Line2D at 0x7ff4ed6f6090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff4ed66fe10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff4ed6b7e10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff4ed7ba950>,
#   <matplotlib.lines.Line2D at 0x7ff4ed779c90>]}

# %%
df_comb['hourly_rate'].min()
# Out:
# 15

# %%
df_comb[df_comb['has_badge']].describe()
# Out:
#        hourly_rate  number_of_ratings profile_picture       rating  \
# count  1752.000000        1752.000000            1752  1618.000000
# mean     58.652968          33.619863       0.8681507     4.815637
# std      26.506456          83.345129       0.3384235     0.360027
# min      15.000000           0.000000           False     1.000000
# 25%      45.000000           3.000000               1     4.800000
# 50%      50.000000           8.000000               1     5.000000
# 75%      65.000000          25.000000               1     5.000000
# max     400.000000        1037.000000            True     5.000000
#
#              STATA        Cello        Yoga Microsoft PowerPoint Biochemistry  \
# count         1752         1752        1752                 1752         1752
# mean   0.003424658  0.003424658  0.01769406            0.1558219   0.05479452
# std     0.05843696   0.05843696   0.1318746              0.36279    0.2276437
# min          False        False       False                False        False
# 25%              0            0           0                    0            0
# 50%              0            0           0                    0            0
# 75%              0            0           0                    0            0
# max           True         True        True                 True         True
#
#       Sign Language     ...      badge_hours has_badge  has_rating  Bachelors  \
# count          1752     ...      1752.000000      1752        1752       1752
# mean     0.00456621     ...       106.900685         1  0.07648402  0.5268265
# std      0.06743853     ...       308.103779         0   0.2658469  0.4994224
# min           False     ...         5.000000      True       False      False
# 25%               0     ...        10.000000         1           0          0
# 50%               0     ...        20.000000         1           0          1
# 75%               0     ...        50.000000         1           0          1
# max            True     ...      5000.000000      True        True       True
#
#              J.D.         MBA          MD         MEd    Masters         PhD
# count        1752        1752        1752        1752       1752        1752
# mean   0.02340183  0.05079909  0.01541096  0.03538813  0.3413242  0.06164384
# std     0.1512192   0.2196499   0.1232158   0.1848115  0.4742893   0.2405762
# min         False       False       False       False      False       False
# 25%             0           0           0           0          0           0
# 50%             0           0           0           0          0           0
# 75%             0           0           0           0          1           0
# max          True        True        True        True       True        True
#
# [8 rows x 274 columns]

# %%
df_comb['hourly_rate'].hist(bins=50)

# %%
print df_comb['has_rating'].value_counts()
df_comb[['hourly_rate','badge_hours']].plot(kind='scatter', x='badge_hours', y='hourly_rate', alpha=0.2, c='r')
# Out:
# True     3847
# False    1979
# dtype: int64

# %%
test = df_comb[['hourly_rate', 'zip_code']]
test['zip_code'] = test['zip_code'].fillna(value=str(0)).apply(lambda x: int(x))

test.plot(kind='scatter', x='zip_code', y='hourly_rate', alpha=0.2, c='r')
plt.axis([10000, 12000, 0, 400])
# Out:
# -c:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# [10000, 12000, 0, 400]

# %%
test[test['zip_code']<8000]
# Out:
#       hourly_rate  zip_code
# 1372           69      7601
# 1374           50      7310
# 1377           55      7013
# 1384          120      7024
# 1389           50      7302
# 1390           65      7040
# 1392           55      7052
# 1394          135      7666
# 1395           50      7302
# 1399           45      7834
# 1406           50      7866
# 1408           40      7042
# 1409           65      7042
# 1414           50      7748
# 1421           60      7110
# 1422           70      7042
# 1424           75      7076
# 1426           45      7003
# 1428           85      7039
# 1429           60      7302
# 1432           60      7036
# 1440           60      7010
# 1441           90      7481
# 1442           75      7083
# 1445           60      7306
# 1448           90      7960
# 1450           60      7604
# 1452           50      7067
# 1454           75      7039
# 1457           40      7095
# ...           ...       ...
# 5693           60      6897
# 5695           50      7728
# 5697           50      7059
# 5699           45      7746
# 5702           45      7726
# 5703          100      6897
# 5704           55      7041
# 5705           30      7738
# 5708           75      7753
# 5710           60      7922
# 5725          110      6820
# 5732           65      7920
# 5738           60      6851
# 5742           40      6902
# 5743           30      6905
# 5748           45      7960
# 5752           50      7302
# 5754           65      7481
# 5759           50      7481
# 5760           40      7869
# 5761           30      7648
# 5765           65      7646
# 5768           60      7670
# 5775           24      7728
# 5776           75      6840
# 5785           80      7960
# 5800           60      7641
# 5807           50      7751
# 5824           30      7960
# 5825           45      6880
#
# [1511 rows x 2 columns]
