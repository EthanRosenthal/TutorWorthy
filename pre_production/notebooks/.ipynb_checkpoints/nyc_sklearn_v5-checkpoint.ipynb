# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import pickle
import itertools
import json
import re
import sklearn

from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing
from sklearn import grid_search
from sklearn.externals import joblib

sns.set()

# %%
cd ../data/sklearn/
# Out:
# /home/ethan/Documents/insight/data/sklearn

# %%
X = pickle.load(open('X.pkl', 'rb'))
y = pickle.load(open('y.pkl', 'rb'))
scaler_X = pickle.load(open('scaler_X.pkl', 'rb'))
scaler_y = pickle.load(open('scaler_y.pkl', 'rb'))

# %%
# Save for later
X_train, X_final_test, y_train, y_final_test = \
    cross_validation.train_test_split(X, \
                                      y, \
                                      test_size=.2, \
                                      random_state=19)
# Cross-validation
kf = cross_validation.KFold(X_train.shape[0], \
                            n_folds=10, \
                            shuffle=True, \
                            random_state=13)

# %%
cd ..
# Out:
# /home/ethan/Documents/insight/data

# %%
possible_subjects = pickle.load(open('possible_subjects.pkl', 'rb'))
feature_labels = [ 'EdD', 'Enrolled', \
                            'Graduate_Coursework', 'J.D.', 'MBA', 'MD', \
                            'MEd', 'Masters', 'Other', 'PhD', \
                            'avg_review_length', 'badge_hours', \
                            'days_since_last_review', 'has_badge', \
                            'has_rating', 'lat', 'lon', \
                            'number_of_ratings', 'number_of_reviews', \
                            'profile_picture', 'rating', 'zip_code', \
                            'zip_radius', 'rating_x_number_of_ratings']
feature_labels_w_subjects = list(feature_labels) # make copy
feature_labels_w_subjects.extend(possible_subjects)

# %%
cd ../scripts/
# Out:
# /home/ethan/Documents/insight/scripts

# %%
import cleanup_features

# %%
cd ../data/
# Out:
# /home/ethan/Documents/insight/data

# %%
clean = pickle.load(open('cleanup_features_object_v2.pkl','rb'))

# %%
i = 0
plt.figure(figsize=(16,16))

for label in feature_labels:
    plt.subplot(6,4,i)
    plt.scatter(x=clean.df[label].as_matrix().astype(np.float), y=clean.df['hourly_rate'].as_matrix().astype(np.float), alpha=.2)
    plt.title(label, fontsize=20)
    i+=1
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_subplots.py:69: MatplotlibDeprecationWarning: The use of 0 (which ends up being the _last_ sub-plot) is deprecated in 1.4 and will raise an error in 1.5
#   mplDeprecation)

# %%
plt.scatter(x=clean.df['lon'], y=clean.df['lat'])
# plt.axis([-74.05, -73.85, 40.68, 40.9])

# %%
tmp = clean.df[['hourly_rate', 'lat', 'lon']]

# %%
tmp2 = tmp.groupby(['lat', 'lon'], as_index=False).aggregate(np.mean)
tmp2.plot(kind='scatter', x='lon', y='lat', c='hourly_rate', cmap='jet', vmin=30, vmax=80)
plt.axis([-74.05, -73.85, 40.68, 40.9])
# Out:
# [-74.05, -73.85, 40.68, 40.9]

# %%
clean.df[clean.df['avg_review_length']>0].plot(kind='scatter', x='avg_review_length', y='hourly_rate', alpha=.2)
# plt.axis([0, 2000, 0, 400])
