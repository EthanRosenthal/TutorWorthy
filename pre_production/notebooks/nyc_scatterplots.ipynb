# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import pickle
import itertools
import json
import re
import sklearn

from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing
from sklearn import grid_search
from sklearn.externals import joblib

sns.set()

# %%
cd ../data/sklearn/only_badges/
# Out:
# /home/ethan/Documents/insight/data/sklearn/only_badges

# %%
X = pickle.load(open('X.pkl', 'rb'))
y = pickle.load(open('y.pkl', 'rb'))
scaler_X = pickle.load(open('scaler_X.pkl', 'rb'))
scaler_y = pickle.load(open('scaler_y.pkl', 'rb'))

# %%
# Save for later
X_train, X_final_test, y_train, y_final_test = \
    cross_validation.train_test_split(X, \
                                      y, \
                                      test_size=.2, \
                                      random_state=19)
# Cross-validation
kf = cross_validation.KFold(X_train.shape[0], \
                            n_folds=10, \
                            shuffle=True, \
                            random_state=13)

# %%
cd ../../
# Out:
# /home/ethan/Documents/insight/data

# %%
feature_labels = pickle.load(open('usable_features.pkl', 'rb'))
# usable_features = [ 'EdD', 'Enrolled', \
#                 'Graduate_Coursework', 'J.D.', 'MBA', 'MD', \
#                 'MEd', 'Masters', 'Other', 'PhD', \
#                 'avg_review_length', 'badge_hours', \
#                 'days_since_last_review', \
#                 'has_rating', 'lat', 'lon', \
#                 'number_of_ratings', 'number_of_reviews', \
#                 'profile_picture', 'rating', 'zip_code', \
#                 'zip_radius', 'rating_x_number_of_ratings', \
#                 'has_ivy_degree', 'has_background_check', \
#                 'days_since_background_check', 'response_time', \
#                 'avg_review_sentiment']

# usable_features.extend(self.clean.cat_features)
# usable_features.extend(self.clean.possible_subjects)
# usable_features.extend(self.clean.qualified_subjects)

# %%
cd ../scripts/
# Out:
# /home/ethan/Documents/insight/scripts

# %%
import cleanup_features

# %%
cd ../data/
# Out:
# /home/ethan/Documents/insight/data

# %%
clean = pickle.load(open('cleanup_features_object_v4.pkl', 'rb'))

# %%
# Out:
# [u'cat_art',
#  u'cat_business',
#  u'cat_computer',
#  u'cat_corporate_training',
#  u'cat_elementary_education',
#  u'cat_english',
#  u'cat_history',
#  u'cat_homeschool',
#  u'cat_language',
#  u'cat_math',
#  u'cat_music',
#  u'cat_science',
#  u'cat_special_needs',
#  u'cat_sports_recreation',
#  u'cat_test_preparation']

# %%
i = 1
plt.figure(figsize=(16,16))

for label in feature_labels[:28]:
    plt.subplot(7,4,i)
    plt.scatter(x=clean.df[label].as_matrix().astype(np.float), y=clean.df['hourly_rate'].as_matrix().astype(np.float), alpha=.2)
    plt.title(label, fontsize=20)
    i+=1
plt.tight_layout()
plt.show()

# %%
i = 1
plt.figure(figsize=(16,16))

for label in feature_labels[:28]:
    plt.subplot(7,4,i)
    plt.scatter(x=X[:,i-1], y=y, alpha=.2)
    plt.title(label, fontsize=20)
    i+=1
plt.tight_layout()
plt.show()

# %%
i = 1
plt.figure(figsize=(16,16))

for label in feature_labels[:28]:
    plt.subplot(7,4,i)
    plt.hist(X[:,i-1], bins=50)
    plt.title(label, fontsize=20)
    i+=1
plt.tight_layout()
plt.show()

# %%
# Out:
# (array([ 229.,  114.,  186.,  158.,   62.,  109.,   98.,   47.,   61.,
#           44.,   45.,   36.,   35.,   31.,   20.,   24.,   20.,   19.,
#           22.,   16.,   17.,   22.,   15.,   15.,   13.,    8.,   11.,
#           10.,    7.,   11.,    7.,   12.,   11.,   15.,    7.,    7.,
#            3.,    3.,    1.,    1.,    3.,    1.,    1.,    1.,    0.,
#            0.,    0.,    1.,    0.,    5.]),
#  array([-1.74007141, -1.65487856, -1.56968571, -1.48449286, -1.3993    ,
#         -1.31410715, -1.2289143 , -1.14372145, -1.0585286 , -0.97333575,
#         -0.88814289, -0.80295004, -0.71775719, -0.63256434, -0.54737149,
#         -0.46217863, -0.37698578, -0.29179293, -0.20660008, -0.12140723,
#         -0.03621437,  0.04897848,  0.13417133,  0.21936418,  0.30455703,
#          0.38974988,  0.47494274,  0.56013559,  0.64532844,  0.73052129,
#          0.81571414,  0.900907  ,  0.98609985,  1.0712927 ,  1.15648555,
#          1.2416784 ,  1.32687125,  1.41206411,  1.49725696,  1.58244981,
#          1.66764266,  1.75283551,  1.83802837,  1.92322122,  2.00841407,
#          2.09360692,  2.17879977,  2.26399262,  2.34918548,  2.43437833,
#          2.51957118]),
#  <a list of 50 Patch objects>)
