# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import itertools
import json
import re
import sklearn

from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing

sns.set()
matplotlib.rcParams['savefig.dpi'] = 1.5 * matplotlib.rcParams['savefig.dpi']

# %%
path = 'nyc_20150115.txt'
df = DataFrame([json.loads(line) for line in open(path)])

# %%
## Just get the subjects (ignore topics)
just_subjects = df['raw_subjects']
just_subjects = just_subjects.apply(lambda x: x.values()) # Get rid of topics
just_subjects = just_subjects.apply(lambda x: list(set(y.strip(' ') for z in x for y in z))) # Flatten lists (see below for better?)
just_subjects.name = 'just_subjects'
df = pd.concat([df, just_subjects], axis=1)
df.head()
# Out:
#                      badge                                          education  \
# 0   Over 50 tutoring hours  {u'Universidad de Barcelona': [u'MEd'], u'Inst...
# 1  Over 400 tutoring hours                            {u'no_university': u''}
# 2  Over 100 tutoring hours  {u'Yale College': [u'History'], u'Columbia Uni...
# 3  Over 200 tutoring hours  {u'University of California at Santa Barbara':...
# 4  Over 100 tutoring hours  {u'Massachusets Institute of Technology': [u'E...
#
#    hourly_rate                                    linked_subjects       name  \
# 0          120  {u'Homeschool': [], u'Language': [], u'Corpora...   Pablo E.
# 1          150                          {u'Test Preparation': []}      JD M.
# 2          140  {u'Test Preparation': [], u'Business': [], u'C...  Horace G.
# 3           60  {u'English': [], u'Homeschool': [], u'Elementa...  Cheryl F.
# 4          120  {u'Sports/Recreation': [], u'Business': [], u'...   Malik K.
#
#    number_of_ratings profile_picture  \
# 0                 30            True
# 1                106            True
# 2                 66            True
# 3                 20            True
# 4                  7            True
#
#                                        qual_subjects  rating  \
# 0  {u'Homeschool': [], u'Language': [], u'Corpora...       5
# 1                          {u'Test Preparation': []}       5
# 2  {u'Test Preparation': [u'ACT English, ', u'ACT...       5
# 3  {u'English': [u'English, ', u'Literature, ', u...       5
# 4  {u'Sports/Recreation': [], u'Business': [u'Mic...       5
#
#                                         raw_subjects zip_code zip_radius  \
# 0  {u'Homeschool': [u'Spanish'], u'Language': [u'...    10028          3
# 1                   {u'Test Preparation': [u'LSAT']}    10036         40
# 2  {u'Test Preparation': [u'ACT English', u'ACT M...    10019         40
# 3  {u'English': [u'English', u'ESL/ESOL', u'Gramm...    10012         40
# 4  {u'Sports/Recreation': [u'Martial Arts'], u'Bu...    10030         10
#
#                                        just_subjects
# 0                                          [Spanish]
# 1                                             [LSAT]
# 2  [ACT Science, SAT Writing, SAT Reading, Busine...
# 3  [Literature, Grammar, Vocabulary, Elementary (...
# 4  [SAT Math, ACT English, Calculus, ACT Science,...

# %% [markdown]
# ## Convert subject mentions to boolean features

# %%
possible_subjects = list(set(itertools.chain.from_iterable(df['just_subjects'].values)))

# %%
dummies_df = DataFrame(columns=possible_subjects, dtype='Bool')

def subj_to_bool(row, categories):
    """ Convert subjects to boolean values"""
    out_row = []
    for subj in categories:
        if subj in row:
            out_row.append(True)
        else:
            out_row.append(False)
    return np.array(out_row)

# %%
# Make new boolean column for each subject. Place in dummies_df DataFrame
for i in xrange(0, df.shape[0]):
    dummies_df.loc[i] = subj_to_bool(df['just_subjects'].loc[i], possible_subjects)
dummies_df.head()
# Out:
#    STATA  Cello   Yoga Microsoft PowerPoint Biochemistry Sign Language  \
# 0  False  False  False                False        False         False
# 1  False  False  False                False        False         False
# 2  False  False  False                False        False         False
# 3  False  False  False                False        False         False
# 4  False  False  False                False        False         False
#
#   Microbiology  Tango ACT English Music History    ...    Series 63  \
# 0        False  False       False         False    ...        False
# 1        False  False       False         False    ...        False
# 2        False  False        True         False    ...        False
# 3        False  False       False         False    ...        False
# 4        False  False        True         False    ...        False
#
#   Networking (Computer) Visual Basic Spanish Trombone Violin Bible Studies  \
# 0                 False        False    True    False  False         False
# 1                 False        False   False    False  False         False
# 2                 False        False   False    False  False         False
# 3                 False        False   False    False  False         False
# 4                 False        False   False    False  False         False
#
#    NCLEX   Film Geography
# 0  False  False     False
# 1  False  False     False
# 2  False  False     False
# 3  False  False     False
# 4  False  False     False
#
# [5 rows x 260 columns]

# %%
df_comb = pd.concat([df, dummies_df], axis=1)

# %% [markdown]
# ## Plot average hourly rate with standard deviation vs. mention of subject

# %%
def hourly_rate_by_subject(df, column):
    out = {}
    for subject in column:
        tmp = df[df[subject]==True]['hourly_rate']
        out[subject] = {'mean':tmp.mean(), 'stdev':tmp.std()}
    return DataFrame(out).transpose()

hourly_subject_rates = hourly_rate_by_subject(df_comb, possible_subjects)
hourly_subject_rates.head()
# Out:
#                   mean      stdev
# ACT English  62.549170  32.083528
# ACT Math     64.237265  32.186349
# ACT Reading  62.472557  31.120801
# ACT Science  68.115607  35.950504
# ADD/ADHD     58.624444  19.464978

# %%
hourly_subject_rates = hourly_subject_rates.sort(axis=0, columns='mean')

# %%
current_palette = sns.color_palette()

# %%
fig, ax = plt.subplots()

plt.errorbar(np.linspace(0,1,len(hourly_subject_rates.index.tolist())), \
             hourly_subject_rates['mean'], yerr=hourly_subject_rates['stdev'], \
             ecolor=current_palette[2], alpha=0.5)
plt.xticks(np.linspace(0,1,len(hourly_subject_rates.index.tolist())/20), \
           hourly_subject_rates.index.tolist()[::20], rotation=40, \
           horizontalalignment='right')

plt.axis([0, 1, 0, 180])
plt.xlabel('Tutoring Subject', fontsize=16)
plt.ylabel('Hourly Rate', fontsize=16)

# %% [markdown]
# ## Convert badge info to hours and boolean

# %%
numbers_regex = re.compile('\d+')

def get_badge_info(row, numbers_regex):
    row_regex = re.findall(numbers_regex, row)
    if len(row_regex)==1:
        return Series({'has_badge':True, 'badge_hours':int(row_regex[0])})
    else:
        return Series({'has_badge':False, 'badge_hours':0})

badge_df = df['badge'].apply(lambda x: get_badge_info(x, numbers_regex))
badge_df.head()
# Out:
#    badge_hours has_badge
# 0           50      True
# 1          400      True
# 2          100      True
# 3          200      True
# 4          100      True

# %%
df_comb = pd.concat([df_comb, badge_df], axis=1)
df_comb = df_comb.drop('badge', axis=1)
df_comb.head()
# Out:
#                                            education  hourly_rate  \
# 0  {u'Universidad de Barcelona': [u'MEd'], u'Inst...          120
# 1                            {u'no_university': u''}          150
# 2  {u'Yale College': [u'History'], u'Columbia Uni...          140
# 3  {u'University of California at Santa Barbara':...           60
# 4  {u'Massachusets Institute of Technology': [u'E...          120
#
#                                      linked_subjects       name  \
# 0  {u'Homeschool': [], u'Language': [], u'Corpora...   Pablo E.
# 1                          {u'Test Preparation': []}      JD M.
# 2  {u'Test Preparation': [], u'Business': [], u'C...  Horace G.
# 3  {u'English': [], u'Homeschool': [], u'Elementa...  Cheryl F.
# 4  {u'Sports/Recreation': [], u'Business': [], u'...   Malik K.
#
#    number_of_ratings profile_picture  \
# 0                 30            True
# 1                106            True
# 2                 66            True
# 3                 20            True
# 4                  7            True
#
#                                        qual_subjects  rating  \
# 0  {u'Homeschool': [], u'Language': [], u'Corpora...       5
# 1                          {u'Test Preparation': []}       5
# 2  {u'Test Preparation': [u'ACT English, ', u'ACT...       5
# 3  {u'English': [u'English, ', u'Literature, ', u...       5
# 4  {u'Sports/Recreation': [], u'Business': [u'Mic...       5
#
#                                         raw_subjects zip_code    ...     \
# 0  {u'Homeschool': [u'Spanish'], u'Language': [u'...    10028    ...
# 1                   {u'Test Preparation': [u'LSAT']}    10036    ...
# 2  {u'Test Preparation': [u'ACT English', u'ACT M...    10019    ...
# 3  {u'English': [u'English', u'ESL/ESOL', u'Gramm...    10012    ...
# 4  {u'Sports/Recreation': [u'Martial Arts'], u'Bu...    10030    ...
#
#   Visual Basic Spanish Trombone Violin Bible Studies  NCLEX   Film Geography  \
# 0        False    True    False  False         False  False  False     False
# 1        False   False    False  False         False  False  False     False
# 2        False   False    False  False         False  False  False     False
# 3        False   False    False  False         False  False  False     False
# 4        False   False    False  False         False  False  False     False
#
#   badge_hours has_badge
# 0          50      True
# 1         400      True
# 2         100      True
# 3         200      True
# 4         100      True
#
# [5 rows x 274 columns]

# %% [markdown]
# ## Cleanup ratings and convert to boolean

# %%
has_rating = df_comb['rating'].apply(lambda x: np.isnan(x))
has_rating.name = 'has_rating'
df_comb = pd.concat([df_comb, has_rating], axis=1)

# %%
df_comb['rating'].apply(lambda x: np.isnan(x))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 5806    False
# 5807     True
# 5808     True
# 5809     True
# 5810    False
# 5811    False
# 5812    False
# 5813    False
# 5814    False
# 5815    False
# 5816    False
# 5817    False
# 5818    False
# 5819    False
# 5820     True
# Name: rating, Length: 5821, dtype: bool

# %%
subject_sort = df_comb[df_comb[possible_subjects]==True][possible_subjects].sum()
subject_sort.sort()
print subject_sort.describe()
# Out:
# count     260.000000
# mean      285.496154
# std       466.720601
# min         1.000000
# 25%        32.750000
# 50%        96.500000
# 75%       289.500000
# max      2756.000000
# dtype: float64

# %%
subject_sort.plot(fontsize=12)
plt.xlabel('Tutoring Subject', fontsize=16)
plt.ylabel('Counts', fontsize=16)

# %% [markdown]
# ## Play with some scikit-learn

# %%
y = df_comb['hourly_rate'].as_matrix().astype(np.float32)

# %%
df_comb.head()
# Out:
#                                            education  hourly_rate  \
# 0  {u'Universidad de Barcelona': [u'MEd'], u'Inst...          120
# 1                            {u'no_university': u''}          150
# 2  {u'Yale College': [u'History'], u'Columbia Uni...          140
# 3  {u'University of California at Santa Barbara':...           60
# 4  {u'Massachusets Institute of Technology': [u'E...          120
#
#                                      linked_subjects       name  \
# 0  {u'Homeschool': [], u'Language': [], u'Corpora...   Pablo E.
# 1                          {u'Test Preparation': []}      JD M.
# 2  {u'Test Preparation': [], u'Business': [], u'C...  Horace G.
# 3  {u'English': [], u'Homeschool': [], u'Elementa...  Cheryl F.
# 4  {u'Sports/Recreation': [], u'Business': [], u'...   Malik K.
#
#    number_of_ratings profile_picture  \
# 0                 30            True
# 1                106            True
# 2                 66            True
# 3                 20            True
# 4                  7            True
#
#                                        qual_subjects  rating  \
# 0  {u'Homeschool': [], u'Language': [], u'Corpora...       5
# 1                          {u'Test Preparation': []}       5
# 2  {u'Test Preparation': [u'ACT English, ', u'ACT...       5
# 3  {u'English': [u'English, ', u'Literature, ', u...       5
# 4  {u'Sports/Recreation': [], u'Business': [u'Mic...       5
#
#                                         raw_subjects zip_code    ...      \
# 0  {u'Homeschool': [u'Spanish'], u'Language': [u'...    10028    ...
# 1                   {u'Test Preparation': [u'LSAT']}    10036    ...
# 2  {u'Test Preparation': [u'ACT English', u'ACT M...    10019    ...
# 3  {u'English': [u'English', u'ESL/ESOL', u'Gramm...    10012    ...
# 4  {u'Sports/Recreation': [u'Martial Arts'], u'Bu...    10030    ...
#
#   Spanish Trombone Violin Bible Studies  NCLEX   Film Geography badge_hours  \
# 0    True    False  False         False  False  False     False          50
# 1   False    False  False         False  False  False     False         400
# 2   False    False  False         False  False  False     False         100
# 3   False    False  False         False  False  False     False         200
# 4   False    False  False         False  False  False     False         100
#
#   has_badge has_rating
# 0      True      False
# 1      True      False
# 2      True      False
# 3      True      False
# 4      True      False
#
# [5 rows x 275 columns]

# %%
X_features = ['profile_picture', 'has_badge', 'has_rating']
X_features.extend(possible_subjects)
X = df_comb[X_features].as_matrix().astype(np.float)

scaler = preprocessing.StandardScaler()
X = scaler.fit_transform(X)

# %%
def stratified_cv(X, y, clf_class):
    skf = cross_validation.StratifiedKFold(y, n_folds=10, shuffle=True)
    y_pred = y.copy()
    for train_index, test_index in skf:
        X_train, X_test = X[train_index], X[test_index]
        y_train = y[train_index]
        clf_class.fit(X_train, y_train)
        y_pred[test_index] = clf_class.predict(X_test)
    return y_pred

# %%
clf_lin = sklearn.linear_model.LinearRegression()
stratified_cv(X, y, clf_lin)
# Out:
# /home/ethan/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:413: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=10.
#   % (min_labels, self.n_folds)), Warning)
# array([ 57.03755951,  62.18008423,  93.6135025 , ...,  42.36628342,
#         54.26221085,  82.03726959], dtype=float32)

# %% [raw]
# def remove_sparse_subjects(df, subjects, threshold):

# %%
def fix_masters(ed_list):
    fixed_list = []
    for degree in ed_list:
        if degree=='Master&#39;s':
            fixed_list.append('Masters')
        else:
            fixed_list.append(degree)
    return fixed_list

ed = df_comb['education'].apply(lambda x: [v[0] for v in x.itervalues() if len(v)>0])
ed = ed.apply(lambda x: fix_masters(x))

def get_education(ed_list):
    degrees = {'MEd':False, 'MBA':False, 'Masters':False, 'PhD':False, 'J.D.':False, 'MD':False}
    check = True
    for degree in degrees.keys():
        if degree in ed_list:
            degrees[degree] = True
            check = False
    degrees['Bachelors'] = check
    return Series(degrees)

ed = ed.apply(lambda x: get_education(x))

print ed
# Out:
#      Bachelors   J.D.    MBA     MD    MEd Masters    PhD
# 0        False  False   True  False   True   False  False
# 1         True  False  False  False  False   False  False
# 2        False  False  False  False  False    True  False
# 3        False  False  False  False  False    True  False
# 4         True  False  False  False  False   False  False
# 5        False   True  False  False  False    True  False
# 6         True  False  False  False  False   False  False
# 7         True  False  False  False  False   False  False
# 8        False  False  False  False  False    True  False
# 9        False  False  False  False  False    True  False
# 10        True  False  False  False  False   False  False
# 11        True  False  False  False  False   False  False
# 12        True  False  False  False  False   False  False
# 13       False   True  False  False  False   False  False
# 14        True  False  False  False  False   False  False
# 15       False  False  False  False  False   False   True
# 16        True  False  False  False  False   False  False
# 17        True  False  False  False  False   False  False
# 18       False  False  False  False  False   False   True
# 19       False  False  False  False  False    True  False
# 20       False  False  False  False  False    True   True
# 21        True  False  False  False  False   False  False
# 22        True  False  False  False  False   False  False
# 23       False  False  False  False  False    True   True
# 24       False  False  False  False  False    True  False
# 25        True  False  False  False  False   False  False
# 26       False  False  False  False  False    True  False
# 27       False  False  False  False  False    True  False
# 28        True  False  False  False  False   False  False
# 29        True  False  False  False  False   False  False
# ...        ...    ...    ...    ...    ...     ...    ...
# 5791      True  False  False  False  False   False  False
# 5792     False  False  False  False  False    True  False
# 5793     False  False  False  False  False    True  False
# 5794      True  False  False  False  False   False  False
# 5795      True  False  False  False  False   False  False
# 5796      True  False  False  False  False   False  False
# 5797      True  False  False  False  False   False  False
# 5798      True  False  False  False  False   False  False
# 5799      True  False  False  False  False   False  False
# 5800     False  False  False  False  False    True  False
# 5801      True  False  False  False  False   False  False
# 5802      True  False  False  False  False   False  False
# 5803     False  False  False  False  False    True  False
# 5804     False  False  False  False  False    True  False
# 5805      True  False  False  False  False   False  False
# 5806     False  False   True  False  False    True  False
# 5807     False  False  False  False  False    True  False
# 5808     False  False  False  False  False   False   True
# 5809     False  False  False  False  False    True  False
# 5810     False  False  False  False  False    True  False
# 5811     False  False  False  False  False    True  False
# 5812      True  False  False  False  False   False  False
# 5813      True  False  False  False  False   False  False
# 5814      True  False  False  False  False   False  False
# 5815      True  False  False  False  False   False  False
# 5816      True  False  False  False  False   False  False
# 5817     False  False  False  False  False    True  False
# 5818      True  False  False  False  False   False  False
# 5819      True  False  False  False  False   False  False
# 5820     False   True   True  False  False   False  False
#
# [5821 rows x 7 columns]

# %%
df_comb = pd.concat([df_comb, ed], axis=1)
df_comb.head()
# Out:
#                                            education  hourly_rate  \
# 0  {u'Universidad de Barcelona': [u'MEd'], u'Inst...          120
# 1                            {u'no_university': u''}          150
# 2  {u'Yale College': [u'History'], u'Columbia Uni...          140
# 3  {u'University of California at Santa Barbara':...           60
# 4  {u'Massachusets Institute of Technology': [u'E...          120
#
#                                      linked_subjects       name  \
# 0  {u'Homeschool': [], u'Language': [], u'Corpora...   Pablo E.
# 1                          {u'Test Preparation': []}      JD M.
# 2  {u'Test Preparation': [], u'Business': [], u'C...  Horace G.
# 3  {u'English': [], u'Homeschool': [], u'Elementa...  Cheryl F.
# 4  {u'Sports/Recreation': [], u'Business': [], u'...   Malik K.
#
#    number_of_ratings profile_picture  \
# 0                 30            True
# 1                106            True
# 2                 66            True
# 3                 20            True
# 4                  7            True
#
#                                        qual_subjects  rating  \
# 0  {u'Homeschool': [], u'Language': [], u'Corpora...       5
# 1                          {u'Test Preparation': []}       5
# 2  {u'Test Preparation': [u'ACT English, ', u'ACT...       5
# 3  {u'English': [u'English, ', u'Literature, ', u...       5
# 4  {u'Sports/Recreation': [], u'Business': [u'Mic...       5
#
#                                         raw_subjects zip_code  ...    \
# 0  {u'Homeschool': [u'Spanish'], u'Language': [u'...    10028  ...
# 1                   {u'Test Preparation': [u'LSAT']}    10036  ...
# 2  {u'Test Preparation': [u'ACT English', u'ACT M...    10019  ...
# 3  {u'English': [u'English', u'ESL/ESOL', u'Gramm...    10012  ...
# 4  {u'Sports/Recreation': [u'Martial Arts'], u'Bu...    10030  ...
#
#   badge_hours has_badge has_rating Bachelors   J.D.    MBA     MD    MEd  \
# 0          50      True      False     False  False   True  False   True
# 1         400      True      False      True  False  False  False  False
# 2         100      True      False     False  False  False  False  False
# 3         200      True      False     False  False  False  False  False
# 4         100      True      False      True  False  False  False  False
#
#   Masters    PhD
# 0   False  False
# 1   False  False
# 2    True  False
# 3    True  False
# 4   False  False
#
# [5 rows x 282 columns]

# %%
df_comb[df_comb['Bachelors']==True]['hourly_rate'].describe()
# Out:
# count    3569.000000
# mean       53.559260
# std        21.526028
# min        15.000000
# 25%        40.000000
# 50%        50.000000
# 75%        60.000000
# max       400.000000
# Name: hourly_rate, dtype: float64

# %%
degrees = ['Bachelors', 'J.D.', 'MBA', 'MEd', 'Masters', 'PhD']

degree_plot = DataFrame()
for degree in degrees:
    d = Series(df_comb[df_comb[degree]==True]['hourly_rate'], name=degree)
    degree_plot = pd.concat([degree_plot, d], axis=1)

degree_plot.boxplot(fontsize=12)
plt.ylim(0, 150)
plt.xlabel('Degree', fontsize=16)
plt.ylabel('Hourly Rate', fontsize=16)

# %%
plt.boxplot(df_comb[df_comb['PhD']]['hourly_rate'].as_matrix(), whis='range')
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f18b4b6ae50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f18b4a95050>,
#   <matplotlib.lines.Line2D at 0x7f18b4ab3d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f18b4a3a790>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f18b4a755d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f18b4b6aed0>,
#   <matplotlib.lines.Line2D at 0x7f18b4b3e190>]}

# %%
df_comb[df_comb['hourly_rate']>200]
# Out:
#                                               education  hourly_rate  \
# 53    {u'Columbia Law School': [u'J.D.'], u'Yale': [...          250
# 77       {u'Harvard College': [u'Physics, Philosophy']}          400
# 229   {u'Emerson College BFA program': [u''], u'BFA ...          250
# 230   {u'Cornell University': [u'English'], u'Columb...          300
# 264   {u'Oxford University (UK)': [u'Master&#39;s'],...          250
# 742          {u'Kansas State University': [u'Finance']}          299
# 748   {u'New York University': [u'Comp Lit and Nat S...          250
# 3136                 {u'Reed College': [u'Psychology']}          300
# 3160  {u'Stanford University': [u'Master&#39;s'], u'...          225
#
#                                         linked_subjects        name  \
# 53    {u'Test Preparation': [], u'Business': [], u'C...    Grant M.
# 77    {u'Art': [], u'Sports/Recreation': [], u'Langu...     John M.
# 229                       {u'Art': [], u'Business': []}    Marta M.
# 230   {u'Homeschool': [], u'Elementary Education': [...     Lisa K.
# 264   {u'Science': [], u'Language': [], u'Corporate ...   Simona A.
# 742   {u'Test Preparation': [], u'Computer': [], u'H...  Cameron A.
# 748   {u'Test Preparation': [], u'Language': [], u'C...    Sandy B.
# 3136  {u'Computer': [], u'Art': [], u'Sports/Recreat...   Andrew R.
# 3160  {u'Sports/Recreation': [], u'Business': [], u'...   Jeremy T.
#
#       number_of_ratings profile_picture  \
# 53                   13            True
# 77                    7            True
# 229                   0            True
# 230                   6            True
# 264                   0            True
# 742                   3            True
# 748                   0            True
# 3136                  0           False
# 3160                  0            True
#
#                                           qual_subjects  rating  \
# 53    {u'Test Preparation': [u'ACT English, ', u'ACT...       5
# 77    {u'Art': [u'Art History, ', u'Art Theory , '],...       5
# 229                       {u'Art': [], u'Business': []}     NaN
# 230   {u'Homeschool': [], u'Elementary Education': [...       5
# 264   {u'Science': [u'Philosophy'], u'Language': [u'...     NaN
# 742   {u'Test Preparation': [], u'Computer': [], u'H...       5
# 748   {u'Test Preparation': [u'SAT Math, ', u'SAT Re...     NaN
# 3136  {u'Computer': [u'Adobe Illustrator, ', u'Adobe...     NaN
# 3160  {u'Sports/Recreation': [], u'Business': [u'Mic...     NaN
#
#                                            raw_subjects zip_code  ...    \
# 53    {u'Test Preparation': [u'ACT English', u'ACT R...    10011  ...
# 77    {u'Art': [u'Art History', u'Art Theory ', u'Ba...    10027  ...
# 229    {u'Art': [u'Film'], u'Business': [u'Marketing']}    10003  ...
# 230   {u'Homeschool': [u'English', u'Writing'], u'El...    10028  ...
# 264   {u'Science': [u'Philosophy'], u'Language': [u'...    10003  ...
# 742   {u'Test Preparation': [u'CFA', u'GMAT'], u'Com...    10003  ...
# 748   {u'Test Preparation': [u'SAT Math', u'SAT Read...    10128  ...
# 3136  {u'Computer': [u'Adobe Illustrator', u'Adobe P...    11211  ...
# 3160  {u'Sports/Recreation': [u'Swimming'], u'Busine...    11217  ...
#
#      badge_hours has_badge has_rating Bachelors   J.D.    MBA     MD    MEd  \
# 53            20      True      False     False   True  False  False  False
# 77            50      True      False      True  False  False  False  False
# 229            0     False       True      True  False  False  False  False
# 230            5      True      False     False  False  False  False  False
# 264            0     False       True     False  False  False  False  False
# 742           20      True      False      True  False  False  False  False
# 748            0     False       True     False  False  False  False  False
# 3136           0     False       True      True  False  False  False  False
# 3160          20      True       True     False  False  False  False  False
#
#      Masters    PhD
# 53     False  False
# 77     False  False
# 229    False  False
# 230     True  False
# 264     True   True
# 742    False  False
# 748     True  False
# 3136   False  False
# 3160    True  False
#
# [9 rows x 282 columns]

# %%
test.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-afac8e150c66> in <module>()
# ----> 1 test.max()
#
# NameError: name 'test' is not defined
